# %%
import pandas as pd

# %%
df = pd.read_csv('Resources/cities.csv')
df
# Out:
#      Unnamed: 0           City  Cloudiness Country        Date  Humidity  \
# 0             0       chunskiy          99      RU  1580229963        91
# 1             1         torbay          90      CA  1580229963        95
# 2             2        qaanaaq          96      GL  1580229964        80
# 3             3  moose factory          90      CA  1580229964        84
# 4             4   murdochville         100      CA  1580229964        89
# ..          ...            ...         ...     ...         ...       ...
# 537         537         sindor          98      RU  1580230050        97
# 538         538         inuvik          40      CA  1580230050        67
# 539         539      bathsheba          75      BB  1580230050        70
# 540         540       kamenica          90      DE  1580229887        75
# 541         541       udachnyy         100      RU  1580230051        91
#
#       Temp    Lat     Lng  Wind Speed
# 0     6.96  56.08   99.63        1.32
# ...

# %%
df_1 = df.drop(columns=['Unnamed: 0'], axis=1)
df_1
# Out:
#               City  Cloudiness Country        Date  Humidity   Temp    Lat  \
# 0         chunskiy          99      RU  1580229963        91   6.96  56.08
# 1           torbay          90      CA  1580229963        95  34.00  47.67
# 2          qaanaaq          96      GL  1580229964        80 -11.74  77.48
# 3    moose factory          90      CA  1580229964        84   3.20  51.26
# 4     murdochville         100      CA  1580229964        89  11.86  48.96
# ..             ...         ...     ...         ...       ...    ...    ...
# 537         sindor          98      RU  1580230050        97  -4.43  62.86
# 538         inuvik          40      CA  1580230050        67 -22.00  68.35
# 539      bathsheba          75      BB  1580230050        70  84.20  13.22
# 540       kamenica          90      DE  1580229887        75  41.00  50.83
# 541       udachnyy         100      RU  1580230051        91   3.42  66.42
#
#         Lng  Wind Speed
# 0     99.63        1.32
# ...

# %%
df_1.to_html('Resources/cities.html')
